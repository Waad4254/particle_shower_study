# %%
from scipy.optimize import minimize, rosen, rosen_der,approx_fprime

# %%
from numpy.random import rand

# %%
import numpy as np

# %%
def objective_functionVec(X, H, G, A, lamda):
    # Regularization
    term1 = np.sum(np.power(X - np.ones(X.shape), 2))
    # Occlusion based penalty

    mat_C = X * np.power(np.ones(N)-G,lamda) * np.ones((N,N))
    mat_D = G * np.ones((N,N))
    term2 = np.sum(np.power(mat_C * H.transpose() * mat_D , 2))
    
    # Occlusion based penalty 2

    mat_A = X * np.power(np.ones(N)-G,lamda) * np.ones((N,N))
    mat_B = G * np.ones((N,N))
    term3 = np.sum(np.power(mat_A * H * mat_B , 2))

    # smoothness

    mat_E = X * np.ones((N,N))
    mat_F = X.transpose() * np.ones((N,N))
    term4 = np.sum(A * np.power(mat_E - mat_F, 2))
    
    return term1 + term2 + term3 + term4

# %%
from numpy import array, dot
from qpsolvers import solve_qp

linesNo = 1000
sigmentsNo = 4
N = linesNo * sigmentsNo

# G is the local importance => 0.5
# A adjacency matrix
# H occlusion matrix

np.random.seed(10)
O = np.random.random(N)

G = 0.5 * np.ones(N)
G = np.diag(G)
H = np.random.random((N,N))
A = np.random.binomial(n=1, p=0.5, size=[N,N])
I = np.identity(N)
D = A # change this to the backward difference operator

print(N, G.shape[0]
#{ 1.0f, 2.0f, 0.2f, 0.3f, 5.0f };//p, q, r, s, lambda
coff1_p = 1.0
coff2_q = 2.0
coff3_r = 0.2
coff4_s = 0.3
coff5_lamda = 5.0

W = np.power((I-G),coff5_lamda) * H * G

#print((I-G))
#print(H)
print(G)
#print(H*G)
#print(W)

Q = coff1_p * I + coff2_q * (W * W.T) + coff3_r * (W.T * W) ;#+ coff4_s * (D.T * D);

c = -1 * np.ones(N);
lb = np.zeros(N);
ub = np.ones(N);

print(Q)
print(Q.shape, c.shape, lb.shape,ub.shape)

x = solve_qp(Q, c, lb=lb,ub=ub, solver="quadprog")
print(f"QP solution: x = {x}")
# Out:
# 4000 4000
# [[0.5 0.  0.  ... 0.  0.  0. ]
#  [0.  0.5 0.  ... 0.  0.  0. ]
#  [0.  0.  0.5 ... 0.  0.  0. ]
#  ...
#  [0.  0.  0.  ... 0.5 0.  0. ]
#  [0.  0.  0.  ... 0.  0.5 0. ]
#  [0.  0.  0.  ... 0.  0.  0.5]]
# [[1.3002102  0.         0.         ... 0.         0.         0.        ]
#  [0.         1.30001477 0.         ... 0.         0.3        0.3       ]
#  [0.         0.         1.00020735 ... 0.         0.         0.        ]
#  ...
#  [0.         0.         0.         ... 1.30044935 0.         0.3       ]
#  [0.         0.3        0.         ... 0.         1.30000866 0.        ]
#  [0.         0.3        0.         ... 0.3        0.         1.30045586]]
# (4000, 4000) (4000,) (4000,) (4000,)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\miniconda3\Lib\site-packages\qpsolvers\solvers\quadprog_.py:92, in quadprog_solve_problem(problem, initvals, verbose, **kwargs)
#      91 try:
# ---> 92     x, obj, xu, iterations, y, iact = solve_qp(
#      93         qp_G, qp_a, qp_C, qp_b, meq, **kwargs
#      94     )
#      95     solution.found = True
#
# File quadprog\\quadprog.pyx:105, in quadprog.solve_qp()
#
# ValueError: matrix G is not positive definite
#
# The above exception was the direct cause of the following exception:
#
# ProblemError                              Traceback (most recent call last)
# Cell In[9], line 47
#      44 print(Q)
#      45 print(Q.shape, c.shape, lb.shape,ub.shape)
# ---> 47 x = solve_qp(Q, c, lb=lb,ub=ub, solver="quadprog")
#      48 print(f"QP solution: x = {x}")
#
# File ~\miniconda3\Lib\site-packages\qpsolvers\solve_qp.py:135, in solve_qp(P, q, G, h, A, b, lb, ub, solver, initvals, verbose, **kwargs)
#     130     raise NoSolverSelected(
#     131         "Set the `solver` keyword argument to one of the "
#     132         f"available solvers in {available_solvers}"
#     133     )
#     134 problem = Problem(P, q, G, h, A, b, lb, ub)
# --> 135 solution = solve_problem(problem, solver, initvals, verbose, **kwargs)
#     136 return solution.x if solution.found else None
#
# File ~\miniconda3\Lib\site-packages\qpsolvers\solve_problem.py:81, in solve_problem(problem, solver, initvals, verbose, **kwargs)
#      79 kwargs["verbose"] = verbose
#      80 try:
# ---> 81     return solve_function[solver](problem, **kwargs)
#      82 except KeyError as e:
#      83     raise SolverNotFound(
#      84         f"found solvers {available_solvers} "
#      85         f"but '{solver}' is not one of them; if '{solver}' is "
#      86         f"listed in https://github.com/qpsolvers/qpsolvers#solvers "
#      87         f"you can run ``pip install qpsolvers[{solver}]``"
#      88     ) from e
#
# File ~\miniconda3\Lib\site-packages\qpsolvers\solvers\quadprog_.py:116, in quadprog_solve_problem(problem, initvals, verbose, **kwargs)
#     113 error_message = str(error)
#     114 if "matrix G is not positive definite" in error_message:
#     115     # quadprog writes G the cost matrix that we write P in this package
# --> 116     raise ProblemError("matrix P is not positive definite") from error
#     117 if "no solution" not in error_message:
#     118     warnings.warn(f"quadprog raised a ValueError: {error_message}")
#
# ProblemError: matrix P is not positive definite
